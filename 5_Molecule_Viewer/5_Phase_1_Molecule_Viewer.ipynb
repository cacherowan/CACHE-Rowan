# %% [markdown]
# # Molecule Viewer

# %%
import py3Dmol

import ipywidgets as widgets

# %% [markdown]
# ## Tutorial: 1

# %% [markdown]
# ### <span style="color:Green">**Propanol**</span>
#
# <span style="color:Yellow">**SMILES: CCCO**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**3**</sub>**H**<sub style="color:red;">**8**</sub>**O**</span>

# %%
with open("Propanol(C3H8O).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_17863798128204648"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17863798128204648" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ## Tutorial: 2

# %% [markdown]
# <a id="title"></a>
# ### <span style="color:Green">**Carbon Dioxide**</span>
#
# <span style="color:Yellow">**SMILES: O=C=O**</span>
#
# <span style="color:Red">**Chemical Formula: CO**<sub style="color:red;">**2**</sub></span>

# %%
with open("Carbon_Dioxide(CO_2).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812827911"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812827911" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Carbon Monoxide**</span>
#
# <span style="color:Yellow">**SMILES: [C-]#[O+]**</span>
#
# <span style="color:Red">**Chemical Formula: CO**</span>

# %%
with open("Carbon_Monoxide(CO).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_17863798128347259"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17863798128347259" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Hydrogen Peroxide**</span>
#
# <span style="color:Yellow">**SMILES: [H]OO[H]**</span>
#
# <span style="color:Red">**Chemical Formula: H**<sub style="color:red;">**2**</sub>**O**<sub style="color:red;">**2**</sub></span>

# %%
with open("Hydrogen_Peroxide(H2O2).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_17863798128764632"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17863798128764632" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Methane**</span>
#
# <span style="color:Yellow">**SMILES: C**</span>
#
# <span style="color:Red">**Chemical Formula: CH**<sub style="color:red;">**4**</sub></span>

# %%
with open("Methane(CH4).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812882968"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812882968" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ## Model Validation Metrics

# %% [markdown]
# ### <span style="color:Green">**Ammonia**</span>
#
# <span style="color:Yellow">**SMILES: N**</span>
#
# <span style="color:Red">**Chemical Formula: NH**<sub style="color:red;">**3**</sub></span>

# %%
with open("Ammonia(NH3).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812889368"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812889368" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Methanol**</span>
#
# <span style="color:Yellow">**SMILES: CO**</span>
#
# <span style="color:Red">**Chemical Formula: CH**<sub style="color:red;">**4**</sub>**O**</span>

# %%
with open("Methanol(CH4O).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812897728"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812897728" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Propane**</span>
#
# <span style="color:Yellow">**SMILES: CCC**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**3**</sub>**H**<sub style="color:red;">**8**</sub></span>

# %%
with open("Propane(C3H8).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812903677"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812903677" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %% [markdown]
# ### <span style="color:Green">**Thiophene**</span>
#
# <span style="color:Yellow">**SMILES: c1ccsc1**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**4**</sub>**H**<sub style="color:red;">**4**</sub>**S**</span>
#
# Base<sub style="color:red;">subscript</sub>

# %%
with open("Thiophene(C4H4S).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786379812909025"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786379812909025" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
