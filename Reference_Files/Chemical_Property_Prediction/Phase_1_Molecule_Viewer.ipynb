# %% [markdown]
# ---
# title: Molecule Viewer
# ---

# %%
import py3Dmol

import ipywidgets as widgets

# %% [markdown]
# ## Tutorial: 1

# %% [markdown]
# ### <span style="color:Green">**Propanol**</span>
#
# <span style="color:Yellow">**SMILES: CCCO**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**3**</sub>**H**<sub style="color:red;">**8**</sub>**O**</span>

# %%
with open("Propanol(C3H8O).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# <div id="3dmolviewer_1786307756256305"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_1786307756256305" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_1786307756256305 = null;
# var warn = document.getElementById("3dmolwarning_1786307756256305");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1786307756256305 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1786307756256305"),{backgroundColor:"white"});
# viewer_1786307756256305.zoomTo();
# 	viewer_1786307756256305.addModel("12\nProperties=species:S:1:pos:R:3:forces:R:3:energies:R:1 energy=-5292.078377858851 stress=\"-9.778965124369646e-09 -4.6819491037182104e-09 -2.7233076546224208e-09 -4.6819491037182104e-09 1.7336451028613675e-09 2.656055333043552e-10 -2.7233076546224208e-09 2.656055333043552e-10 3.850448375293157e-09\" free_energy=-5292.078377858851 pbc=\"F F F\"\nC       -1.32237809      -0.00762953       0.50292134      -0.00099761      -0.00096234      -0.00070120   -1038.04062964\nC       -0.15554929       0.65462303      -0.21878167      -0.00110023       0.00111404       0.00222101   -1038.04627026\nC        0.92013970      -0.33393249      -0.63744524       0.00070668       0.00054232      -0.00104867   -1038.19736177\nO        1.49250455      -1.03157943       0.46360451       0.00233096       0.00205551      -0.00000124   -2048.13465955\nH       -2.07382626       0.72390286       0.79475006       0.00190038       0.00206701      -0.00145074     -16.23690992\nH       -0.97990974      -0.52347500       1.39729782      -0.00074308      -0.00050643       0.00056654     -16.24544807\nH       -1.80479517      -0.74501141      -0.13889810      -0.00248396      -0.00260147       0.00033102     -16.23766611\nH       -0.50834451       1.17176587      -1.11341146       0.00309984       0.00061014      -0.00154073     -16.19827867\nH        0.29501939       1.41860771       0.42051214      -0.00137578      -0.00134652       0.00162467     -16.20301097\nH        0.48941289      -1.10539322      -1.27503424      -0.00029746       0.00127234       0.00123328     -16.12415591\nH        1.69771292       0.17559175      -1.21374289      -0.00198214      -0.00174263       0.00011897     -16.14378396\nH        1.95001361      -0.39747015       1.01822773       0.00094239      -0.00050198      -0.00135291     -16.27020304\n","xyz");
# 	viewer_1786307756256305.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_1786307756256305.zoomTo();
# 	viewer_1786307756256305.zoom(2);
# viewer_1786307756256305.render();
# });
# </script>

# %% [markdown]
# ## Tutorial: 2

# %% [markdown]
# ### <span style="color:Green">**Propanol**</span>
#
# <span style="color:Yellow">**SMILES: CCCO**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**3**</sub>**H**<sub style="color:red;">**8**</sub>**O**</span>
#
# Base<sub style="color:red;">subscript</sub>

# %%
with open("Carbon_Dioxide(CO_2).xyz") as f:
    xyz = f.read()
view = py3Dmol.view(width=800, height=400)
view.addModel(xyz, "xyz")
view.setStyle({"stick": {}, "sphere": {"scale": 0.3}})
view.zoomTo()
view.zoom(2)
view.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 with open("Carbon_Dioxide(CO_2).xyz") as f:
#       2     xyz = f.read()
#       3 view = py3Dmol.view(width=800, height=400)
#       4 view.addModel(xyz, "xyz")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Carbon_Dioxide(CO_2).xyz'

# %% [markdown]
# ### <span style="color:Green">**Propanol**</span>
#
# <span style="color:Yellow">**SMILES: CCCO**</span>
#
# <span style="color:Red">**Chemical Formula: C**<sub style="color:red;">**3**</sub>**H**<sub style="color:red;">**8**</sub>**O**</span>
#
# Base<sub style="color:red;">subscript</sub>
